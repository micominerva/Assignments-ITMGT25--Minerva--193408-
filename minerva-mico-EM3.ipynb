# %% [markdown]
# ## End of Module Assessment 3

# %% [markdown]
# Your org implemented a Google Form for your Recweek, but it was not able to design it well enough to prevent ambiguous data entry.You are tasked to clean up a csv of fake, dirty data called **recweekdata.csv** (presumably exported from some spreadsheet).
#
# In addition, you have a file named **studentprofiles.csv** which has first and last names plus the genders of the students.
#
# The output of this assignment is to convert recweekdata.csv into usable data for statistics. Submit the following files through GitHub:
# 1. A cleaned recweekdata.csv called **cleanrecweekdata.csv**
# 2. This notebook, containing the code (properly commented) that you used to clean the data
#
# Your solution **must use Pandas and possibly Numpy**.
#
# Avoid using loops as much as you can. If I see loops where Pandas vectorization operations are more appropriate, you will receive deductions.
#
# Hint(s):
# * if you need to apply scalar (regular single-value) functions on Pandas columns, use the Pandas Dataframe .apply(...) function
#
# Clearly show your output similiar to what you see in this notebook.
#
# #### Required Statistics
#
# 1. How many people were born in each month?
# 2. How many people were born on each day?
# 3. How many people were born in each year?
# 4. How many people come from each course?
# 5. How many people per year level?
# 6. How many people have numbers from Globe (0917 or 0927) and Smart (0918)? *Note: it's up to you how to format this output*
# 7. How many Globe subscribers are: Male? Female?
# 8. How many Smart subscribers are: Male? Female?

# %%
# start of code; add as many cells as needed
import pandas as pd

# %%
# the outputs below use the dataframe variable name recweek

# %%
# check header
# Out:
#   firstname   lastname birthmonth  birthday  birthyear      course  yearlevel  \
# 0     name1  lastname1         11        26       1998       BS LM          2
# 1     name2  lastname2        May        26       2001  Management          4
# 2     name3  lastname3          5        16       1997      BS CTM          1
# 3     name4  lastname4        Dec         9         97      BS ITE          3
# 4     name5  lastname5        Sep         5         97      BS CTM          3
#
#         phonenumber
# 0  +63 918 302 6210
# 1      927 212 6276
# 2  +63 918 253 7017
# 3      918 714 4360
# 4  +63 927 462 1674

# %%
# write code here

recweek = pd.read_csv("recweekdata.csv")
recweek.head()
# Out:
#   firstname   lastname birthmonth  birthday  birthyear      course  yearlevel  \
# 0     name1  lastname1         11        26       1998       BS LM          2
# 1     name2  lastname2        May        26       2001  Management          4
# 2     name3  lastname3          5        16       1997      BS CTM          1
# 3     name4  lastname4        Dec         9         97      BS ITE          3
# 4     name5  lastname5        Sep         5         97      BS CTM          3
#
#         phonenumber
# 0  +63 918 302 6210
# 1      927 212 6276
# 2  +63 918 253 7017
# 3      918 714 4360
# 4  +63 927 462 1674

# %%
# check tail
# Out:
#      firstname      lastname birthmonth  birthday  birthyear  \
# 2995  name2996  lastname2996      March        28         97
# 2996  name2997  lastname2997        May        19       1998
# 2997  name2998  lastname2998       July         3         98
# 2998  name2999  lastname2999         12         2         98
# 2999  name3000  lastname3000        Jul        13       1997
#
#                 course  yearlevel       phonenumber
# 2995            BS CTM          2      917 795 5051
# 2996                LM          2      917 445 3378
# 2997               ITE          2      917 154 5694
# 2998                ME          3      927 497 8977
# 2999  Legal Management          1  +63 918 719 7624

# %%
# write code here

recweek.tail()
# Out:
#      firstname      lastname birthmonth  birthday  birthyear  \
# 2995  name2996  lastname2996      March        28         97
# 2996  name2997  lastname2997        May        19       1998
# 2997  name2998  lastname2998       July         3         98
# 2998  name2999  lastname2999         12         2         98
# 2999  name3000  lastname3000        Jul        13       1997
#
#                 course  yearlevel       phonenumber
# 2995            BS CTM          2      917 795 5051
# 2996                LM          2      917 445 3378
# 2997               ITE          2      917 154 5694
# 2998                ME          3      927 497 8977
# 2999  Legal Management          1  +63 918 719 7624

# %%
# Clean Month

# dump recweek data
recweek
# Out:
#      firstname      lastname birthmonth  birthday  birthyear  \
# 0        name1     lastname1   November        26       1998
# 1        name2     lastname2        May        26       2001
# 2        name3     lastname3        May        16       1997
# 3        name4     lastname4   December         9         97
# 4        name5     lastname5  September         5         97
# ...        ...           ...        ...       ...        ...
# 2995  name2996  lastname2996      March        28         97
# 2996  name2997  lastname2997        May        19       1998
# 2997  name2998  lastname2998       July         3         98
# 2998  name2999  lastname2999   December         2         98
# 2999  name3000  lastname3000       July        13       1997
#
#                 course  yearlevel       phonenumber
# 0                BS LM          2  +63 918 302 6210
# 1           Management          4      927 212 6276
# 2               BS CTM          1  +63 918 253 7017
# ...

# %%
# write code here

dirty_set = set(recweek["birthmonth"])
clean_dict = {raw:None for raw in dirty_set}

for i in clean_dict:
    clean_dict[i] = input(i+" Enter Month:")
    
recweek.replace(clean_dict, inplace=True)
# Out:
# 2 Enter Month:February
# 8 Enter Month:August
# July Enter Month:July
# Mar Enter Month:March
# 10 Enter Month:October
# Dec Enter Month:December
# Jul Enter Month:July
# 12 Enter Month:December
# 11 Enter Month:November
# May Enter Month:May
# 9 Enter Month:September
# 4 Enter Month:April
# April Enter Month:April
# 7 Enter Month:July
# Sep Enter Month:September
# December Enter Month:December
# Nov Enter Month:November
# November Enter Month:November
# 3 Enter Month:March
# 5 Enter Month:May
# Aug Enter Month:August
# September Enter Month:September
# March Enter Month:March
# June Enter Month:June
# Oct Enter Month:October
# Feb Enter Month:February
# February Enter Month:February
# Apr Enter Month:April
# Jun Enter Month:June
# August Enter Month:August
# Jan Enter Month:January
# 6 Enter Month:June
# January Enter Month:January
# 1 Enter Month:January

# %%
# Clean Year

# dump recweek data
recweek
# Out:
#      firstname      lastname birthmonth  birthday birthyear            course  \
# 0        name1     lastname1   November        26      1998             BS LM
# 1        name2     lastname2        May        26      2001        Management
# 2        name3     lastname3        May        16      1997            BS CTM
# 3        name4     lastname4   December         9      1997            BS ITE
# 4        name5     lastname5  September         5      1997            BS CTM
# ...        ...           ...        ...       ...       ...               ...
# 2995  name2996  lastname2996      March        28      1997            BS CTM
# 2996  name2997  lastname2997        May        19      1998                LM
# 2997  name2998  lastname2998       July         3      1998               ITE
# 2998  name2999  lastname2999   December         2      1998                ME
# 2999  name3000  lastname3000       July        13      1997  Legal Management
#
# ...

# %%
# Clean Course

# dump recweek data
recweek
# Out:
#      firstname      lastname birthmonth  birthday birthyear  \
# 0        name1     lastname1   November        26      1998
# 1        name2     lastname2        May        26      2001
# 2        name3     lastname3        May        16      1997
# 3        name4     lastname4   December         9      1997
# 4        name5     lastname5  September         5      1997
# ...        ...           ...        ...       ...       ...
# 2995  name2996  lastname2996      March        28      1997
# 2996  name2997  lastname2997        May        19      1998
# 2997  name2998  lastname2998       July         3      1998
# 2998  name2999  lastname2999   December         2      1998
# 2999  name3000  lastname3000       July        13      1997
#
#                             course  yearlevel       phonenumber
# 0              BS Legal Management          2  +63 918 302 6210
# 1                    BS Management          4      927 212 6276
# ...

# %%
# mobile number cleaning

# dump recweek data
recweek
# Out:
#      firstname      lastname birthmonth  birthday birthyear  \
# 0        name1     lastname1   November        26      1998
# 1        name2     lastname2        May        26      2001
# 2        name3     lastname3        May        16      1997
# 3        name4     lastname4   December         9      1997
# 4        name5     lastname5  September         5      1997
# ...        ...           ...        ...       ...       ...
# 2995  name2996  lastname2996      March        28      1997
# 2996  name2997  lastname2997        May        19      1998
# 2997  name2998  lastname2998       July         3      1998
# 2998  name2999  lastname2999   December         2      1998
# 2999  name3000  lastname3000       July        13      1997
#
#                             course  yearlevel    phonenumber
# 0              BS Legal Management          2  0918 302 6210
# 1                    BS Management          4  0927 212 6276
# ...

# %%
dirty_set = set(recweek["birthyear"])
clean_dict = {raw:None for raw in dirty_set}

for i in clean_dict:
    clean_dict[i] = input(str(i)+" Enter Clean:")
    
recweek.replace(clean_dict, inplace=True)

dirty_set = set(recweek["course"])
clean_dict = {raw:None for raw in dirty_set}

for i in clean_dict:
    clean_dict[i] = input(str(i)+" Enter Clean:")
    
recweek.replace(clean_dict, inplace=True)
# Out:
# 97 Enter Clean:1997
# 98 Enter Clean:1998
# 99 Enter Clean:1999
# 1997 Enter Clean:1997
# 1998 Enter Clean:1998
# 1999 Enter Clean:1999
# 2000 Enter Clean:2000
# 2001 Enter Clean:2001
# Communications Technology Enter Clean:BS Communications Technology
# CTM Enter Clean:BS Communications Technology
# LM Enter Clean:BS Legal Management
# ME Enter Clean:BS Management Engineering
# BS ME Enter Clean:BS Management Engineering
# BS LM Enter Clean:BS Legal Management
# MGT Enter Clean:BS Management
# Management Engineering Enter Clean:BS Management Engineering
# Management Enter Clean:BS Management
# BS CTM Enter Clean:BS Communications Technology
# BS MGT Enter Clean:BS Management
# BS ITE Enter Clean:BS IT Entrepreneurship
# ITE Enter Clean:BS IT Entrepreneurship
# Legal Management Enter Clean:BS Legal Management
# Information Technology Entrepreneurship Enter Clean:BS IT Entrepreneurship

# %%
recweek["phonenumber"] = "0"+recweek["phonenumber"].str.slice(start = -12)
#replace(recweek["phonenumber"], r"9[0-9][0-9] ", r"0\1", inplace=True, limit=None, regex=True, method='pad')
recweek
# Out:
#      firstname      lastname birthmonth  birthday birthyear  \
# 0        name1     lastname1   November        26      1998
# 1        name2     lastname2        May        26      2001
# 2        name3     lastname3        May        16      1997
# 3        name4     lastname4   December         9      1997
# 4        name5     lastname5  September         5      1997
# ...        ...           ...        ...       ...       ...
# 2995  name2996  lastname2996      March        28      1997
# 2996  name2997  lastname2997        May        19      1998
# 2997  name2998  lastname2998       July         3      1998
# 2998  name2999  lastname2999   December         2      1998
# 2999  name3000  lastname3000       July        13      1997
#
#                             course  yearlevel    phonenumber
# 0              BS Legal Management          2  0918 302 6210
# 1                    BS Management          4  0927 212 6276
# ...

# %%
# add genders
# hint: load "studentprofiles.csv" as new dataframe and add to our dataframe using Pandas merge(...) function

# dump recweek data
final_recweek
# Out:
#      firstname      lastname  gender birthmonth  birthday birthyear  \
# 0        name1     lastname1  Female   November        26      1998
# 1        name2     lastname2  Female        May        26      2001
# 2        name3     lastname3  Female        May        16      1997
# 3        name4     lastname4    Male   December         9      1997
# 4        name5     lastname5  Female  September         5      1997
# ...        ...           ...     ...        ...       ...       ...
# 2995  name2996  lastname2996  Female      March        28      1997
# 2996  name2997  lastname2997    Male        May        19      1998
# 2997  name2998  lastname2998  Female       July         3      1998
# 2998  name2999  lastname2999    Male   December         2      1998
# 2999  name3000  lastname3000    Male       July        13      1997
#
#                             course  yearlevel    phonenumber
# 0              BS Legal Management          2  0918 302 6210
# ...

# %%
# write code here

student_profiles = pd.read_csv("studentprofiles.csv")
final_recweek = pd.merge(student_profiles,recweek)
final_recweek
#final_recweek["firstname","lastname","gender","birthmonth","birthday","birthyear","course","yearlevel","phonenumber"]
# Out:
#      firstname      lastname  gender birthmonth  birthday birthyear  \
# 0        name1     lastname1  Female   November        26      1998
# 1        name2     lastname2  Female        May        26      2001
# 2        name3     lastname3  Female        May        16      1997
# 3        name4     lastname4    Male   December         9      1997
# 4        name5     lastname5  Female  September         5      1997
# ...        ...           ...     ...        ...       ...       ...
# 2995  name2996  lastname2996  Female      March        28      1997
# 2996  name2997  lastname2997    Male        May        19      1998
# 2997  name2998  lastname2998  Female       July         3      1998
# 2998  name2999  lastname2999    Male   December         2      1998
# 2999  name3000  lastname3000    Male       July        13      1997
#
#                             course  yearlevel    phonenumber
# 0              BS Legal Management          2  0918 302 6210
# ...

# %%
# export to csv
# compare with cleanrecweekdata

# %%
# Use ls (Mac) or dir (Windows) cleanrecweekdata.csv
# choose appropriate command
# !dir cleanrecweekdata.csv
# or
# !ls cleanrecweekdata.csv
# Out:
#  Volume in drive D is UserProfile
#  Volume Serial Number is 508F-1BD0
#
#  Directory of D:\Users\jilagan\Dropbox\Workspaces\src\ITMGT25.03_Intersession2020\tests\EM3
#
# 08/10/2020  04:01 PM           276,118 cleanrecweekdata.csv
#                1 File(s)        276,118 bytes
#                0 Dir(s)  44,855,271,424 bytes free

# %%
# write code here

final_recweek.to_csv("final_recweek.csv")

# %% [markdown]
# #### Get statistics

# %%
# People per Birthmonth sorted by calendar numeric month
# Out:
#    birthmonth  count
# 0     January    270
# 1    February    232
# 2       March    246
# 3       April    267
# 4         May    273
# 5        June    259
# 6        July    249
# 7      August    241
# 8   September    232
# 9     October    178
# 10   November    277
# 11   December    276

# %%
# Write code here

months = {"birthmonth":['January', 'February', 'March', 'April', 'May', 'June', 'July','August', 'September', 'October', 'November', 'December']}
counts = {"count" : [len(final_recweek[final_recweek["birthmonth"]==x]) for x in months["birthmonth"]]}
pd.concat([pd.DataFrame(months),pd.DataFrame(counts)], axis=1)
# Out:
#    birthmonth  count
# 0     January    270
# 1    February    232
# 2       March    246
# 3       April    267
# 4         May    273
# 5        June    259
# 6        July    249
# 7      August    241
# 8   September    232
# 9     October    178
# 10   November    277
# 11   December    276

# %%
# same day
# sort by calendar day
# Out:
#          0
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
# ...    ...
# 2995  2995
# 2996  2996
# 2997  2997
# 2998  2998
# 2999  2999
#
# [3000 rows x 1 columns]

# %%
# write code here

days = {"birthday":[x for x in sorted(set(final_recweek["birthday"]))]}
counts = {"count" : [len(final_recweek[final_recweek["birthday"]==x]) for x in days["birthday"]]}
pd.concat([pd.DataFrame(days),pd.DataFrame(counts)], axis=1)
# Out:
#     birthday  count
# 0          1    112
# 1          2    106
# 2          3     90
# 3          4    110
# 4          5    100
# 5          6     99
# 6          7     88
# 7          8    111
# 8          9     98
# 9         10    111
# 10        11    105
# 11        12     98
# 12        13    119
# 13        14    102
# 14        15    121
# 15        16    115
# 16        17    116
# 17        18    107
# 18        19    113
# 19        20     91
# 20        21    123
# 21        22    103
# 22        23    116
# 23        24    108
# 24        25    116
# 25        26    116
# 26        27    102
# 27        28    104

# %%
# same year
# sort accordingly
# Out:
#   birthyear  count
# 0      1997    756
# 1      1998    746
# 2      1999    756
# 3      2000    380
# 4      2001    362

# %%
# write code here

years = {"birthyear":[x for x in sorted(set(final_recweek["birthyear"]))]}
counts = {"count" : [len(final_recweek[final_recweek["birthyear"]==x]) for x in years["birthyear"]]}
pd.concat([pd.DataFrame(years),pd.DataFrame(counts)], axis=1)
# Out:
#   birthyear  count
# 0      1997    756
# 1      1998    746
# 2      1999    756
# 3      2000    380
# 4      2001    362

# %%
# same year level
# sort accordingly
# Out:
#    yearlevel  count
# 0          1    760
# 1          2    791
# 2          3    751
# 3          4    698

# %%
# write code here

yearlevels = {"yearlevel":[x for x in sorted(set(final_recweek["yearlevel"]))]}
counts = {"count" : [len(final_recweek[final_recweek["yearlevel"]==x]) for x in yearlevels["yearlevel"]]}
pd.concat([pd.DataFrame(yearlevels),pd.DataFrame(counts)], axis=1)
# Out:
#    yearlevel  count
# 0          1    760
# 1          2    791
# 2          3    751
# 3          4    698

# %%
# same course
# sorting does not matter
# Out:
#                          course  count
# 0  BS Communications Technology    589
# 1        BS IT Entrepreneurship    590
# 2           BS Legal Management    585
# 3                 BS Management    629
# 4     BS Management Engineering    607

# %%
# write code here

courses = {"courses":[x for x in set(final_recweek["course"])]}
counts = {"count" : [len(final_recweek[final_recweek["course"]==x]) for x in courses["courses"]]}
pd.concat([pd.DataFrame(courses),pd.DataFrame(counts)], axis=1)
# Out:
#                         courses  count
# 0           BS Legal Management    585
# 1     BS Management Engineering    607
# 2        BS IT Entrepreneurship    590
# 3                 BS Management    629
# 4  BS Communications Technology    589

# %%
# choose any of the following two outputs:
# Out:
# carrier  gender
# Globe    Female     984
#          Male      1061
# Smart    Female     494
#          Male       461
# Name: firstname, dtype: int64

# %%
# or
# Out:
#   carrier  gender  count
# 0   Globe  Female    984
# 1   Globe    Male   1061
# 2   Smart  Female    494
# 3   Smart    Male    461

# %%
# carrier count
# Out:
#   carrier  count
# 0   Globe   2045
# 1   Smart    955

# %%
def carrier_check(x):
    prefix = x[:4]
    if prefix=="0918":return "Smart"
    elif prefix=="0917" or prefix=="0927": return "Globe"

# %%
final_recweek["carrier"]=final_recweek.phonenumber.apply(carrier)

# %%
final_carriers= final_recweek.copy().groupby(["carrier"], as_index=False).count()[["carrier","firstname"]]
# Applies count to all columns, so next step is to choose any column to change into count column.
final_carriers.rename(columns={"firstname":"count"},inplace=True)
final_carriers
# Out:
#   carrier  count
# 0   Globe   2045
# 1   Smart    955
